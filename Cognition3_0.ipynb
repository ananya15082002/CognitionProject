# %% [markdown]
# # Getting Started With Your Machine Learning Project
#
# ## Define the Problem
#
# ### Understand the Objective
# - **Identify the problem**: What are you trying to solve? Examples include increasing sales, reducing churn, or detecting fraud.
# - **Frame it as a machine learning task**: Is it classification, regression, clustering, etc.?
# - **Identify evaluation metrics**: How will you measure success? Examples include accuracy, precision, recall, F1-score, RMSE (Root Mean Squared Error).
#
# ![Problem Solving](image.png)
#
# ## Prepare the Data
#
# ### Collect and Clean Data
# - **Gather data**: Collect data from relevant sources.
# - **Handle missing values**: Decide how to deal with missing data (e.g., remove, fill with mean/median).
# - **Remove outliers**: Identify and handle outliers that can skew your results.
# - **Fix inconsistencies**: Ensure data consistency (e.g., same format for dates).
#
# ### Explore and Visualize Data
# - **Understand the distribution**: Use plots to see how data is distributed.
# - **Identify relationships**: Look for correlations between variables.
# - **Spot patterns**: Find any trends or patterns in the data.
#
# ### Feature Engineering
# - **Transform raw data**: Convert raw data into useful features.
# - **Create new features**: Generate new features that might be helpful for the model.
#
# ### Split the Data
# - **Training set**: Used to train the model.
# - **Validation set**: Used to tune the model.
# - **Testing set**: Used to evaluate the final model.
#
# ## Evaluate Algorithms
#
# ### Select Potential Algorithms
# - **Choose models**: Based on your problem, select models (e.g., linear regression, decision trees, random forests, neural networks).
#
# ### Train and Validate Models
# - **Fit models**: Train your models on the training data.
# - **Evaluate performance**: Use validation data to evaluate models.
#
# ### Compare Model Performance
# - **Use evaluation metrics**: Compare different models using metrics like accuracy, precision, recall, or RMSE.
#
# ## Improve Results
#
# ### Hyperparameter Tuning
# - **Optimize parameters**: Adjust model parameters to improve performance.
#
# ### Feature Selection
# - **Identify important features**: Find out which features contribute most to the model's predictions.
#
# ### Ensemble Methods
# - **Combine models**: Use multiple models together to get better results.
#
# ## Present Results
#
# ### Summarize Findings
# - **Communicate performance**: Clearly explain how well your model performs.
#
# ### Visualize Results
# - **Use charts and graphs**: Present your findings effectively using visual aids.
#
# ### Deploy Your Model
# - **Integrate into production**: Implement your model in a real-world setting for use.
#
# ## Remember
# Each step is iterative. You might need to go back and revisit previous steps based on what you find along the way.

# %% [markdown]
# # Traffic Density Classification
#
# ## Objective
# The goal of this project is to preprocess and analyze an image dataset for traffic density classification. This involves resizing and normalizing images, analyzing dataset statistics, and preparing the data for use in machine learning models.
#
# ## Why It Is Needed
# Traffic density classification is essential for traffic management systems, urban planning, and reducing congestion. By classifying traffic density from images, we can make informed decisions to improve traffic flow and safety.
#
# ## Dataset
# The dataset consists of images of traffic scenes categorized into different classes based on traffic density. Each class represents a different level of traffic density, such as "Empty", "Low", "Medium", "High", and "Traffic Jam". The dataset is organized into three folders: training, validation, and testing, each containing subfolders for different classes.
#
# ### Dataset Structure
# - **Training**
#   - Empty
#   - Low
#   - Medium
#   - High
#   - Traffic Jam
# - **Validation**
#   - Empty
#   - Low
#   - Medium
#   - High
#   - Traffic Jam
# - **Testing**
#   - Empty
#   - Low
#   - Medium
#   - High
#   - Traffic Jam

# %% [markdown]
# # Understanding the Dataset
#
#
# - **Structure**: Each data point in the dataset is an instance represented by multiple features and a corresponding label.
#
# ## Types of Datasets
# 1. **Training Set**: This portion of the dataset is used to train the machine learning model. The model learns the relationship between the features and the label.
# 2. **Validation Set**: This subset is used to tune the hyperparameters of the model. It helps to fine-tune the model to prevent overfitting.
# 3. **Testing Set**: The testing set is used to evaluate the final performance of the model after it has been trained and validated.
#
# Link of the dataset - [text](https://www.kaggle.com/datasets/rahat52/traffic-density-singapore)
# ## Key Steps in Understanding the Dataset
#
# ### 1. Explore the Dataset
# - **View Initial Rows**: Look at the first few rows of the dataset to get an idea of its structure and content.
# - **Identify Features and Labels**: Determine which columns are features (inputs) and which one is the label (output).
# - **Check for Missing Values**: Identify any missing data points that need to be handled.
# - **Spot Outliers**: Detect any outliers that may skew the data analysis or model performance.
# - **Fix Inconsistencies**: Ensure the data is consistent, e.g., date formats should be uniform.
#
# ### 2. Visualize the Data
# - **Distribution of Data**: Use histograms, box plots, and other visualizations to understand the distribution of each feature.
# - **Relationships Between Features**: Use scatter plots, pair plots, and correlation matrices to examine relationships between features and the label.
# - **Patterns in the Data**: Identify any trends or patterns that can be helpful for feature engineering.
#
# ### 3. Analyze Class Distribution
# - **Balance of Classes**: Check the number of instances in each class (for classification problems). Ensure there’s no severe imbalance which could affect model performance.
#
# ### 4. Summary Statistics
# - **Central Tendency**: Calculate mean, median, mode to understand the central values of the features.
# - **Spread of Data**: Calculate variance, standard deviation to understand the spread of the features.
#
# ### 5. Feature Correlation
# - **Correlation Analysis**: Use correlation coefficients to find out how features are related to each other and to the label. Highly correlated features can sometimes be redundant and might be removed.

# %% [markdown]
# # How to Choose a Model
#
# ## Understanding Model Types
#
# ### 1. Supervised Learning
# - **Classification**: Models that predict a categorical label. E.g., determining if an email is spam or not.
# - **Regression**: Models that predict a continuous value. E.g., predicting house prices.
#
# ### 2. Unsupervised Learning
# - **Clustering**: Models that group similar data points together. E.g., customer segmentation.
# - **Dimensionality Reduction**: Models that reduce the number of features while preserving important information. E.g., PCA (Principal Component Analysis).
#
# ### 3. Reinforcement Learning
# - **Learning through Actions**: Models that learn by taking actions in an environment to maximize some notion of cumulative reward. E.g., game playing.
#
# ## Criteria for Choosing a Model
#
# ### 1. Problem Type
# - **Identify the Task**: Is it a classification, regression, clustering, or dimensionality reduction problem?
#
# ### 2. Data Size
# - **Volume of Data**: Some models, like neural networks, perform better with large datasets, while others like KNN work well with smaller datasets.
#
# ### 3. Feature Types
# - **Nature of Features**: Are your features numerical, categorical, textual, or images? Choose models that handle your specific data types well.
#
# ### 4. Interpretability
# - **Understanding the Model**: Some models are easier to interpret (like linear regression), while others are more complex (like deep neural networks). Choose based on your need for interpretability.
#
# ### 5. Training Time
# - **Computation Requirements**: Consider the time it takes to train the model. Some models may take longer to train, especially with large datasets.
#
# ### 6. Performance
# - **Evaluation Metrics**: Use metrics such as accuracy, precision, recall, F1-score, and RMSE to evaluate model performance.
#
#
#
# Choosing the right model involves understanding the problem, the type of data, and the specific requirements of your project. Always start with simpler models and gradually move to more complex ones if needed. Ensure to evaluate models using cross-validation and appropriate metrics to select the best performing model.

# %% [markdown]
# # Model Workflow
# ![workflow](workflow.png)

# %% [markdown]
# 1. Install Necessary Libraries
# We need to install opencv-python-headless for image processing and matplotlib for visualization.
#
# # Install necessary libraries
# !pip install opencv-python-headless matplotlib

# %%
# %pip install opencv-python-headless
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# 2. Import Required Libraries
# We will import the necessary libraries for image processing, file handling, and data visualization.

# %%
# Importing os for interacting with the operating system
import os
# Importing Path from pathlib for handling file paths
from pathlib import Path
# Importing cv2 from opencv-python-headless for image processing
import cv2
# Importing pyplot from matplotlib for plotting and visualization
import matplotlib.pyplot as plt
# Importing numpy for numerical operations on arrays
import numpy as np
import pandas as pd

# %% [markdown]
# 3. Load the Dataset

# %%
## Define the input directory
input_directory = r'C:\Users\asus\Desktop\cognition\dataset\Training'  # Use raw string to handle backslashes #change the path directory

# Initialize lists to store image details
image_details = []

# %% [markdown]
# Data Loading Function
#
# The function load_dataset loads the dataset and returns counts of images per class, image shapes, and total image count.

# %%
# Iterate through the classes (subdirectories)
for class_name in os.listdir(input_directory):
    class_path = os.path.join(input_directory, class_name)
    
    # Iterate through images in the class subdirectory
    for image_name in os.listdir(class_path):
        image_path = os.path.join(class_path, image_name)
        
        # Load the image
        image = cv2.imread(image_path)
        
        # Check if the image is loaded properly
        if image is not None:
            height, width, channels = image.shape
            image_type = image.dtype
            resolution = (height, width)
            
            # Append image details to the list
            image_details.append({
                'image_name': image_name,
                'class': class_name,
                'height': height,
                'width': width,
                'channels': channels,
                'type': image_type,
                'resolution': resolution,
                'path': image_path
            })
# Create a DataFrame from the image details
image_df = pd.DataFrame(image_details)

# Save the DataFrame to a CSV file
image_df.to_csv('image_details.csv', index=False)

# %% [markdown]
# 4. Analyze and Summarize the Dataset
#
#
# Dimensions of the Dataset

# %%
# Detailed exploratory analysis
print("Number of images:", len(image_df))
print("Image classes:", image_df['class'].unique())
print("Average image resolution:", image_df[['height', 'width']].mean())
print("Image types:", image_df['type'].unique())
# Out:
# Number of images: 3659
# Image classes: ['Empty' 'High' 'Low' 'Medium' 'Traffic Jam']
# Average image resolution: height    403.249522
# width     610.744739
# dtype: float64
# Image types: [dtype('uint8')]

# %%
# Class-specific analysis
for class_name in image_df['class'].unique():
    class_df = image_df[image_df['class'] == class_name]
    print(f"\nClass: {class_name}")
    print(f"Number of images: {len(class_df)}")
    print(f"Average height: {class_df['height'].mean()}")
    print(f"Average width: {class_df['width'].mean()}")
    print(f"Height variance: {np.var(class_df['height'])}")
    print(f"Width variance: {np.var(class_df['width'])}")
# Out:
# Class: Empty
# Number of images: 1249
# Average height: 371.2409927942354
# Average width: 558.7830264211369
# Height variance: 8532.086838405874
# Width variance: 19393.234747926443
#
# Class: High
# Number of images: 434
# Average height: 445.5184331797235
# Average width: 639.8364055299539
# Height variance: 3742.3510427063643
# Width variance: 1622.0492737157297
#
# Class: Low
# Number of images: 987
# Average height: 395.258358662614
# Average width: 632.5430597771024
# Height variance: 3658.975803992941
# Width variance: 2330.614913839386
#
# Class: Medium
# Number of images: 741
# Average height: 425.95546558704456
# Average width: 638.9271255060729
# Height variance: 3666.568866888492
# Width variance: 307.6546083364749
#
# Class: Traffic Jam
# Number of images: 248
# Average height: 454.44354838709677
# Average width: 650.5685483870968
# Height variance: 61230.25487773152
# Width variance: 139140.704978538

# %% [markdown]
# Peek at the Data
#
# We will visualize some example images from the dataset.

# %%
class_counts = image_df['class'].value_counts()

plt.figure(figsize=(12, 8))
# Iterate through the first few classes and display an example image from each
for i, (class_name, count) in enumerate(class_counts.items()):
    if i >= 5:  # Display only the first 5 classes
        break
    # Get the path to an example image from the current class
    example_image_path = os.path.join(input_directory, class_name, os.listdir(os.path.join(input_directory, class_name))[0])
    # Load the image using cv2
    example_image = cv2.imread(example_image_path)
    # Convert the image from BGR to RGB (cv2 loads images in BGR format)
    example_image = cv2.cvtColor(example_image, cv2.COLOR_BGR2RGB)
    # Display the image using matplotlib
    plt.subplot(1, 5, i+1)
    plt.imshow(example_image)
    plt.title(class_name)
    plt.axis('off')
plt.show()

# %% [markdown]
# # 5.  Preprocess the Images
#
# Resizing images to a consistent size.
# Converting images to grayscale.
# Applying edge detection
# Normalizing pixel values.
# Saving preprocessed images to the specified output directory.

# %%
# %pip install opencv-python numpy tqdm scikit-image
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.2/38.8 MB 6.9 MB/s eta 0:00:06
#     --------------------------------------- 0.5/38.8 MB 6.8 MB/s eta 0:00:06
#    - -------------------------------------- 1.0/38.8 MB 8.2 MB/s eta 0:00:05
#    - -------------------------------------- 1.5/38.8 MB 9.4 MB/s eta 0:00:04
#    - -------------------------------------- 1.7/38.8 MB 8.9 MB/s eta 0:00:05
#    - -------------------------------------- 1.8/38.8 MB 6.9 MB/s eta 0:00:06
#    -- ------------------------------------- 2.1/38.8 MB 6.8 MB/s eta 0:00:06
#    -- ------------------------------------- 2.4/38.8 MB 6.3 MB/s eta 0:00:06
#    -- ------------------------------------- 2.8/38.8 MB 7.0 MB/s eta 0:00:06
#    --- ------------------------------------ 3.1/38.8 MB 6.6 MB/s eta 0:00:06
#    --- ------------------------------------ 3.3/38.8 MB 6.6 MB/s eta 0:00:06
# ...

# %%
# %pip install scikit-image
# Out:
# ...
#   Using cached scikit_image-0.24.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# ...
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached imageio-2.34.2-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Using cached scikit_image-0.24.0-cp312-cp312-win_amd64.whl (12.9 MB)
# Using cached imageio-2.34.2-py3-none-any.whl (313 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts imageio_download_bin.exe and imageio_remove_bin.exe are installed in 'c:\Users\asus\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# ...

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
from skimage import feature

# %%
def preprocess_image(image_path, output_path, size=(224, 224)):
    """
    Preprocess a single image by resizing, normalizing, and applying edge detection.

    Parameters:
    - image_path: str, path to the input image.
    - output_path: str, path to save the preprocessed image.
    - size: tuple, size to resize the image (default is (224, 224)).
    """
    # Load the image from the given path
    img = cv2.imread(image_path)
    if img is None:
        return  # If image can't be loaded, exit the function

    # Resize the image to the given size
    img_resized = cv2.resize(img, size, interpolation=cv2.INTER_AREA)

    # Convert the image to grayscale
    img_gray = cv2.cvtColor(img_resized, cv2.COLOR_BGR2GRAY)

    # Normalize the pixel values to range between 0 and 1
    img_normalized = img_gray / 255.0

    # Apply Canny edge detection
    edges = feature.canny(img_normalized, sigma=1)

    # Save the preprocessed image
    cv2.imwrite(output_path, (edges * 255).astype(np.uint8))

# %%
def preprocess_dataset(input_dir, output_dir, size=(224, 224)):
    """
    Preprocess all images in the dataset directory.

    Parameters:
    - input_dir: str, path to the input dataset directory.
    - output_dir: str, path to save the preprocessed dataset.
    - size: tuple, size to resize the images (default is (224, 224)).
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # List of class names (directories) in the dataset
    classes = ['Empty', 'High', 'Low', 'Medium', 'Traffic Jam']

    for class_name in classes:
        input_class_dir = os.path.join(input_dir, class_name)
        output_class_dir = os.path.join(output_dir, class_name)
        
        if not os.path.exists(output_class_dir):
            os.makedirs(output_class_dir)
        
        if not os.path.exists(input_class_dir):
            print(f"Directory {input_class_dir} does not exist, skipping.")
            continue
        
        # Iterate over each image file in the class directory
        for img_name in tqdm(os.listdir(input_class_dir), desc=f'Processing {class_name}'):
            input_img_path = os.path.join(input_class_dir, img_name)
            output_img_path = os.path.join(output_class_dir, img_name)
            preprocess_image(input_img_path, output_img_path, size)

# %%
if __name__ == '__main__':
    # Set the input and output directory paths
    input_dir = r'C:\Users\asus\Desktop\cognition\dataset\Training'
    output_dir = r'C:\Users\asus\Desktop\cognition\preprocessed-dataset'
    
    # Preprocess the dataset
    preprocess_dataset(input_dir, output_dir) # type: ignore
# Out:
# ...
# Processing Traffic Jam: 100%|██████████| 248/248 [00:03<00:00, 65.77it/s]
